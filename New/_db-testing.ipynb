# %%
import psycopg2
from sqlalchemy import create_engine
import pandas as pd
import matplotlib.pyplot as plt

# Database connection parameters
db_params = {
    'dbname': 'iroils_db',
    'user': 'iroils_user',
    'password': '3Carrot^^^',
    'host': '192.168.1.8',  # Change to your postgres container on unraid
    'port': '5432'
}

# SQLAlchemy connection string
connection_str = f"postgresql://{db_params['user']}:{db_params['password']}@{db_params['host']}:{db_params['port']}/{db_params['dbname']}"

# Create an SQLAlchemy engine
engine = create_engine(connection_str)

# Query to fetch all data
query = "SELECT * FROM full_events;"

# Execute the query and fetch data into a pandas DataFrame
df = pd.read_sql(query, engine)

# Close the connection
engine.dispose()

# Now df holds all the data in memory, and you can inspect its values
# display(df)

# %%
# Set the display.max_rows option to None to display all rows in the DataFrame
pd.set_option('display.max_rows', None)

# Display the DataFrame as a scrollable table
display(df)

# Reset display.max_rows to default for future DataFrames
# This is to avoid performance issues when printing DataFrames to the output
# pd.reset_option('display.max_rows')
# Out:
#      eventnumber   datetimesubmitted                   classification  \
# 0          78979 2023-09-12 17:23:53                        Near-miss
# 1          78924 2023-09-11 18:53:14  Operational/Process Improvement
# 2          78923 2023-09-11 18:50:53  Operational/Process Improvement
# 3          78883 2023-09-11 11:33:47                        Near-miss
# 4          78695 2023-09-06 12:24:10  Operational/Process Improvement
# 5          78632 2023-09-05 10:13:34  Operational/Process Improvement
# 6          78630 2023-09-05 09:52:33  Operational/Process Improvement
# 7          78446 2023-08-30 09:51:46                        Near-miss
# 8          78433 2023-08-29 17:53:33                 Unsafe condition
# 9          78431 2023-08-29 17:41:35                 Unsafe condition
# 10         78413 2023-08-29 14:47:45  Operational/Process Improvement
# 11         78404 2023-08-29 12:37:19  Operational/Process Improvement
# ...
